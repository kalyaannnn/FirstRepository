# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
G = nx.DiGraph()

# %%
G.add_edges_from([('A','D'),('B','C'),('B','E'),('C','A'),('D','C'),('E','D'),('E','B'),('E','F'),('E','C'),('F','C'),('F','H'),('G','A'),('G','C'),('H','A')])

# %%
plt.figure(figsize = (10,10))
nx.draw_networkx(G,with_labels = True)

# %%
hubs,authorities = nx.hits(G,max_iter = 50,normalized = True)
print("Hub Scores",hubs)
print("Authority Scores",authorities)
# Out:
# Hub Scores {'A': 0.04642540403219996, 'D': 0.1336603752611538, 'B': 0.1576359944296732, 'C': 0.03738913224642653, 'E': 0.2588144598468665, 'F': 0.1576359944296732, 'H': 0.03738913224642653, 'G': 0.17104950750758033}
# Authority Scores {'A': 0.10864044011724343, 'D': 0.13489685434358004, 'B': 0.11437974073336447, 'C': 0.388372800387618, 'E': 0.06966521184241475, 'F': 0.11437974073336447, 'H': 0.06966521184241477, 'G': 0.0}
